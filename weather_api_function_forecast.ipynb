# %%
import requests
import json
from pprint import pprint
def get_weather():
    """Get the weather data from openweathermap.org API"""
    
    APIURL = "http://api.openweathermap.org/data/2.5/forecast"
    APIKEY = "2a2976ca391b03a9c1c9f1eba7680faa"
    CITYID = "2965768"
#     Make request and print the data
    request = requests.get(APIURL, params={'id':CITYID,'APPID':APIKEY})
#     return request.text
#     print(request.text)
    data = json.loads(request.text)
#     print(data["city"])
    return data
#     pprint(data)

# %%
weatherData = get_weather()

# %%
pprint(weatherData)
# Out:
# {'city': {'coord': {'lat': 52.8408, 'lon': -6.9262},
#           'country': 'IE',
#           'id': 2965768,
#           'name': 'Carlow'},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 92},
#            'dt': 1551798000,
#            'dt_txt': '2019-03-05 15:00:00',
#            'main': {'grnd_level': 979.2,
#                     'humidity': 77,
#                     'pressure': 994.63,
#                     'sea_level': 994.63,
#                     'temp': 282.79,
#                     'temp_kf': 0.82,
#                     'temp_max': 282.79,
#                     'temp_min': 281.963},
#            'rain': {'3h': 0.145},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 204.001, 'speed': 5.21}},
#           {'clouds': {'all': 92},
#            'dt': 1551808800,
#            'dt_txt': '2019-03-05 18:00:00',
#            'main': {'grnd_level': 976.49,
#                     'humidity': 96,
#                     'pressure': 992.12,
#                     'sea_level': 992.12,
#                     'temp': 280.08,
#                     'temp_kf': 0.62,
#                     'temp_max': 280.08,
#                     'temp_min': 279.46},
#            'rain': {'3h': 1.87},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 113.5, 'speed': 3.89}},
#           {'clouds': {'all': 92},
#            'dt': 1551819600,
#            'dt_txt': '2019-03-05 21:00:00',
#            'main': {'grnd_level': 972.6,
#                     'humidity': 95,
#                     'pressure': 988.1,
#                     'sea_level': 988.1,
#                     'temp': 280.67,
#                     'temp_kf': 0.41,
#                     'temp_max': 280.67,
#                     'temp_min': 280.262},
#            'rain': {'3h': 4.22},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'moderate rain',
#                         'icon': '10n',
#                         'id': 501,
#                         'main': 'Rain'}],
#            'wind': {'deg': 104.5, 'speed': 4.96}},
#           {'clouds': {'all': 92},
#            'dt': 1551830400,
#            'dt_txt': '2019-03-06 00:00:00',
#            'main': {'grnd_level': 966.99,
#                     'humidity': 96,
#                     'pressure': 982.61,
#                     'sea_level': 982.61,
#                     'temp': 280.7,
#                     'temp_kf': 0.21,
#                     'temp_max': 280.7,
#                     'temp_min': 280.498},
#            'rain': {'3h': 4.795},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'moderate rain',
#                         'icon': '10n',
#                         'id': 501,
#                         'main': 'Rain'}],
#            'wind': {'deg': 74.0031, 'speed': 4.71}},
#           {'clouds': {'all': 80},
#            'dt': 1551841200,
#            'dt_txt': '2019-03-06 03:00:00',
#            'main': {'grnd_level': 964.45,
#                     'humidity': 94,
#                     'pressure': 979.99,
#                     'sea_level': 979.99,
#                     'temp': 281.403,
#                     'temp_kf': 0,
#                     'temp_max': 281.403,
#                     'temp_min': 281.403},
#            'rain': {'3h': 1.515},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 195.5, 'speed': 3.07}},
#           {'clouds': {'all': 88},
#            'dt': 1551852000,
#            'dt_txt': '2019-03-06 06:00:00',
#            'main': {'grnd_level': 964.31,
#                     'humidity': 96,
#                     'pressure': 979.75,
#                     'sea_level': 979.75,
#                     'temp': 281.593,
#                     'temp_kf': 0,
#                     'temp_max': 281.593,
#                     'temp_min': 281.593},
#            'rain': {'3h': 0.27},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 210.004, 'speed': 5.47}},
#           {'clouds': {'all': 92},
#            'dt': 1551862800,
#            'dt_txt': '2019-03-06 09:00:00',
#            'main': {'grnd_level': 964.39,
#                     'humidity': 96,
#                     'pressure': 980.02,
#                     'sea_level': 980.02,
#                     'temp': 282.035,
#                     'temp_kf': 0,
#                     'temp_max': 282.035,
#                     'temp_min': 282.035},
#            'rain': {'3h': 1.18},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 206.002, 'speed': 5.12}},
#           {'clouds': {'all': 92},
#            'dt': 1551873600,
#            'dt_txt': '2019-03-06 12:00:00',
#            'main': {'grnd_level': 965.12,
#                     'humidity': 100,
#                     'pressure': 980.78,
#                     'sea_level': 980.78,
#                     'temp': 279.809,
#                     'temp_kf': 0,
#                     'temp_max': 279.809,
#                     'temp_min': 279.809},
#            'rain': {'3h': 2.445},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 329.002, 'speed': 6.16}},
#           {'clouds': {'all': 88},
#            'dt': 1551884400,
#            'dt_txt': '2019-03-06 15:00:00',
#            'main': {'grnd_level': 966.76,
#                     'humidity': 98,
#                     'pressure': 982.22,
#                     'sea_level': 982.22,
#                     'temp': 278.257,
#                     'temp_kf': 0,
#                     'temp_max': 278.257,
#                     'temp_min': 278.257},
#            'rain': {'3h': 1.195},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 326, 'speed': 8.16}},
#           {'clouds': {'all': 92},
#            'dt': 1551895200,
#            'dt_txt': '2019-03-06 18:00:00',
#            'main': {'grnd_level': 968.85,
#                     'humidity': 89,
#                     'pressure': 984.46,
#                     'sea_level': 984.46,
#                     'temp': 278.981,
#                     'temp_kf': 0,
#                     'temp_max': 278.981,
#                     'temp_min': 278.981},
#            'rain': {'3h': 0.069999999999997},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 316.5, 'speed': 7.58}},
#           {'clouds': {'all': 92},
#            'dt': 1551906000,
#            'dt_txt': '2019-03-06 21:00:00',
#            'main': {'grnd_level': 971.43,
#                     'humidity': 90,
#                     'pressure': 987.13,
#                     'sea_level': 987.13,
#                     'temp': 278.782,
#                     'temp_kf': 0,
#                     'temp_max': 278.782,
#                     'temp_min': 278.782},
#            'rain': {'3h': 0.075000000000003},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 302.5, 'speed': 7.26}},
#           {'clouds': {'all': 92},
#            'dt': 1551916800,
#            'dt_txt': '2019-03-07 00:00:00',
#            'main': {'grnd_level': 973.36,
#                     'humidity': 88,
#                     'pressure': 989.02,
#                     'sea_level': 989.02,
#                     'temp': 278.309,
#                     'temp_kf': 0,
#                     'temp_max': 278.309,
#                     'temp_min': 278.309},
#            'rain': {'3h': 0.074999999999999},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 301.003, 'speed': 7.66}},
#           {'clouds': {'all': 48},
#            'dt': 1551927600,
#            'dt_txt': '2019-03-07 03:00:00',
#            'main': {'grnd_level': 974.9,
#                     'humidity': 82,
#                     'pressure': 990.6,
#                     'sea_level': 990.6,
#                     'temp': 277.596,
#                     'temp_kf': 0,
#                     'temp_max': 277.596,
#                     'temp_min': 277.596},
#            'rain': {'3h': 0.004999999999999},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 297.506, 'speed': 8.17}},
#           {'clouds': {'all': 76},
#            'dt': 1551938400,
#            'dt_txt': '2019-03-07 06:00:00',
#            'main': {'grnd_level': 976.39,
#                     'humidity': 82,
#                     'pressure': 992.08,
#                     'sea_level': 992.08,
#                     'temp': 277.501,
#                     'temp_kf': 0,
#                     'temp_max': 277.501,
#                     'temp_min': 277.501},
#            'rain': {'3h': 0.025000000000002},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 295.001, 'speed': 8.61}},
#           {'clouds': {'all': 76},
#            'dt': 1551949200,
#            'dt_txt': '2019-03-07 09:00:00',
#            'main': {'grnd_level': 979.17,
#                     'humidity': 82,
#                     'pressure': 994.84,
#                     'sea_level': 994.84,
#                     'temp': 278.857,
#                     'temp_kf': 0,
#                     'temp_max': 278.857,
#                     'temp_min': 278.857},
#            'rain': {'3h': 0.064999999999998},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 301.006, 'speed': 9.51}},
#           {'clouds': {'all': 36},
#            'dt': 1551960000,
#            'dt_txt': '2019-03-07 12:00:00',
#            'main': {'grnd_level': 982.06,
#                     'humidity': 75,
#                     'pressure': 997.74,
#                     'sea_level': 997.74,
#                     'temp': 281.593,
#                     'temp_kf': 0,
#                     'temp_max': 281.593,
#                     'temp_min': 281.593},
#            'rain': {},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 310.003, 'speed': 10.12}},
#           {'clouds': {'all': 64},
#            'dt': 1551970800,
#            'dt_txt': '2019-03-07 15:00:00',
#            'main': {'grnd_level': 985.1,
#                     'humidity': 70,
#                     'pressure': 1000.74,
#                     'sea_level': 1000.74,
#                     'temp': 282.017,
#                     'temp_kf': 0,
#                     'temp_max': 282.017,
#                     'temp_min': 282.017},
#            'rain': {},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 313.5, 'speed': 8.82}},
#           {'clouds': {'all': 56},
#            'dt': 1551981600,
#            'dt_txt': '2019-03-07 18:00:00',
#            'main': {'grnd_level': 988.33,
#                     'humidity': 70,
#                     'pressure': 1004.18,
#                     'sea_level': 1004.18,
#                     'temp': 280.7,
#                     'temp_kf': 0,
#                     'temp_max': 280.7,
#                     'temp_min': 280.7},
#            'rain': {},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 308.502, 'speed': 6.56}},
#           {'clouds': {'all': 32},
#            'dt': 1551992400,
#            'dt_txt': '2019-03-07 21:00:00',
#            'main': {'grnd_level': 991.66,
#                     'humidity': 80,
#                     'pressure': 1007.64,
#                     'sea_level': 1007.64,
#                     'temp': 278.5,
#                     'temp_kf': 0,
#                     'temp_max': 278.5,
#                     'temp_min': 278.5},
#            'rain': {},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03n',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 298.5, 'speed': 4.56}},
#           {'clouds': {'all': 20},
#            'dt': 1552003200,
#            'dt_txt': '2019-03-08 00:00:00',
#            'main': {'grnd_level': 993.15,
#                     'humidity': 88,
#                     'pressure': 1009.24,
#                     'sea_level': 1009.24,
#                     'temp': 275.168,
#                     'temp_kf': 0,
#                     'temp_max': 275.168,
#                     'temp_min': 275.168},
#            'rain': {},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'few clouds',
#                         'icon': '02n',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 252.507, 'speed': 2.87}},
#           {'clouds': {'all': 68},
#            'dt': 1552014000,
#            'dt_txt': '2019-03-08 03:00:00',
#            'main': {'grnd_level': 993.36,
#                     'humidity': 88,
#                     'pressure': 1009.38,
#                     'sea_level': 1009.38,
#                     'temp': 274.328,
#                     'temp_kf': 0,
#                     'temp_max': 274.328,
#                     'temp_min': 274.328},
#            'rain': {'3h': 0.010000000000002},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 217.503, 'speed': 3.22}},
#           {'clouds': {'all': 80},
#            'dt': 1552024800,
#            'dt_txt': '2019-03-08 06:00:00',
#            'main': {'grnd_level': 992.26,
#                     'humidity': 89,
#                     'pressure': 1008.29,
#                     'sea_level': 1008.29,
#                     'temp': 275.999,
#                     'temp_kf': 0,
#                     'temp_max': 275.999,
#                     'temp_min': 275.999},
#            'rain': {'3h': 0.029999999999998},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 197.501, 'speed': 3.97}},
#           {'clouds': {'all': 92},
#            'dt': 1552035600,
#            'dt_txt': '2019-03-08 09:00:00',
#            'main': {'grnd_level': 990.3,
#                     'humidity': 95,
#                     'pressure': 1006.13,
#                     'sea_level': 1006.13,
#                     'temp': 278.316,
#                     'temp_kf': 0,
#                     'temp_max': 278.316,
#                     'temp_min': 278.316},
#            'rain': {'3h': 0.9},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 187.002, 'speed': 6.12}},
#           {'clouds': {'all': 92},
#            'dt': 1552046400,
#            'dt_txt': '2019-03-08 12:00:00',
#            'main': {'grnd_level': 987.86,
#                     'humidity': 97,
#                     'pressure': 1003.62,
#                     'sea_level': 1003.62,
#                     'temp': 281.107,
#                     'temp_kf': 0,
#                     'temp_max': 281.107,
#                     'temp_min': 281.107},
#            'rain': {'3h': 1.52},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 206, 'speed': 7.96}},
#           {'clouds': {'all': 92},
#            'dt': 1552057200,
#            'dt_txt': '2019-03-08 15:00:00',
#            'main': {'grnd_level': 985.98,
#                     'humidity': 96,
#                     'pressure': 1001.66,
#                     'sea_level': 1001.66,
#                     'temp': 283.07,
#                     'temp_kf': 0,
#                     'temp_max': 283.07,
#                     'temp_min': 283.07},
#            'rain': {'3h': 0.3},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 231.501, 'speed': 6.16}},
#           {'clouds': {'all': 76},
#            'dt': 1552068000,
#            'dt_txt': '2019-03-08 18:00:00',
#            'main': {'grnd_level': 985.62,
#                     'humidity': 90,
#                     'pressure': 1001.17,
#                     'sea_level': 1001.17,
#                     'temp': 282.221,
#                     'temp_kf': 0,
#                     'temp_max': 282.221,
#                     'temp_min': 282.221},
#            'rain': {'3h': 0.09},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 269.502, 'speed': 5.11}},
#           {'clouds': {'all': 92},
#            'dt': 1552078800,
#            'dt_txt': '2019-03-08 21:00:00',
#            'main': {'grnd_level': 985.68,
#                     'humidity': 95,
#                     'pressure': 1001.31,
#                     'sea_level': 1001.31,
#                     'temp': 280.539,
#                     'temp_kf': 0,
#                     'temp_max': 280.539,
#                     'temp_min': 280.539},
#            'rain': {'3h': 0.07},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 245, 'speed': 5.21}},
#           {'clouds': {'all': 92},
#            'dt': 1552089600,
#            'dt_txt': '2019-03-09 00:00:00',
#            'main': {'grnd_level': 985.17,
#                     'humidity': 96,
#                     'pressure': 1000.84,
#                     'sea_level': 1000.84,
#                     'temp': 280.968,
#                     'temp_kf': 0,
#                     'temp_max': 280.968,
#                     'temp_min': 280.968},
#            'rain': {'3h': 0.42},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 252.004, 'speed': 6.86}},
#           {'clouds': {'all': 76},
#            'dt': 1552100400,
#            'dt_txt': '2019-03-09 03:00:00',
#            'main': {'grnd_level': 985.4,
#                     'humidity': 92,
#                     'pressure': 1001.22,
#                     'sea_level': 1001.22,
#                     'temp': 279.739,
#                     'temp_kf': 0,
#                     'temp_max': 279.739,
#                     'temp_min': 279.739},
#            'rain': {'3h': 0.26},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 274, 'speed': 7.17}},
#           {'clouds': {'all': 68},
#            'dt': 1552111200,
#            'dt_txt': '2019-03-09 06:00:00',
#            'main': {'grnd_level': 984.64,
#                     'humidity': 89,
#                     'pressure': 1000.48,
#                     'sea_level': 1000.48,
#                     'temp': 279.204,
#                     'temp_kf': 0,
#                     'temp_max': 279.204,
#                     'temp_min': 279.204},
#            'rain': {'3h': 0.28},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 240.003, 'speed': 8.83}},
#           {'clouds': {'all': 44},
#            'dt': 1552122000,
#            'dt_txt': '2019-03-09 09:00:00',
#            'main': {'grnd_level': 987.81,
#                     'humidity': 87,
#                     'pressure': 1003.57,
#                     'sea_level': 1003.57,
#                     'temp': 278.743,
#                     'temp_kf': 0,
#                     'temp_max': 278.743,
#                     'temp_min': 278.743},
#            'rain': {'3h': 0.81},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 284.502, 'speed': 10.35}},
#           {'clouds': {'all': 20},
#            'dt': 1552132800,
#            'dt_txt': '2019-03-09 12:00:00',
#            'main': {'grnd_level': 991.68,
#                     'humidity': 75,
#                     'pressure': 1007.38,
#                     'sea_level': 1007.38,
#                     'temp': 280.556,
#                     'temp_kf': 0,
#                     'temp_max': 280.556,
#                     'temp_min': 280.556},
#            'rain': {'3h': 0.65},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 271.5, 'speed': 12.25}},
#           {'clouds': {'all': 56},
#            'dt': 1552143600,
#            'dt_txt': '2019-03-09 15:00:00',
#            'main': {'grnd_level': 993.68,
#                     'humidity': 63,
#                     'pressure': 1009.52,
#                     'sea_level': 1009.52,
#                     'temp': 281.516,
#                     'temp_kf': 0,
#                     'temp_max': 281.516,
#                     'temp_min': 281.516},
#            'rain': {},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 275.002, 'speed': 10.96}},
#           {'clouds': {'all': 68},
#            'dt': 1552154400,
#            'dt_txt': '2019-03-09 18:00:00',
#            'main': {'grnd_level': 992.48,
#                     'humidity': 65,
#                     'pressure': 1008.29,
#                     'sea_level': 1008.29,
#                     'temp': 279.75,
#                     'temp_kf': 0,
#                     'temp_max': 279.75,
#                     'temp_min': 279.75},
#            'rain': {},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 259.003, 'speed': 4.82}},
#           {'clouds': {'all': 92},
#            'dt': 1552165200,
#            'dt_txt': '2019-03-09 21:00:00',
#            'main': {'grnd_level': 988.33,
#                     'humidity': 92,
#                     'pressure': 1004.22,
#                     'sea_level': 1004.22,
#                     'temp': 277.639,
#                     'temp_kf': 0,
#                     'temp_max': 277.639,
#                     'temp_min': 277.639},
#            'rain': {'3h': 0.73},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 180.5, 'speed': 4.91}},
#           {'clouds': {'all': 92},
#            'dt': 1552176000,
#            'dt_txt': '2019-03-10 00:00:00',
#            'main': {'grnd_level': 976.83,
#                     'humidity': 95,
#                     'pressure': 992.58,
#                     'sea_level': 992.58,
#                     'temp': 278.343,
#                     'temp_kf': 0,
#                     'temp_max': 278.343,
#                     'temp_min': 278.343},
#            'rain': {'3h': 5.89},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'moderate rain',
#                         'icon': '10n',
#                         'id': 501,
#                         'main': 'Rain'}],
#            'wind': {'deg': 152.003, 'speed': 9.63}},
#           {'clouds': {'all': 92},
#            'dt': 1552186800,
#            'dt_txt': '2019-03-10 03:00:00',
#            'main': {'grnd_level': 965.55,
#                     'humidity': 95,
#                     'pressure': 981.22,
#                     'sea_level': 981.22,
#                     'temp': 278.704,
#                     'temp_kf': 0,
#                     'temp_max': 278.704,
#                     'temp_min': 278.704},
#            'rain': {'3h': 1.92},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 193.505, 'speed': 10.57}},
#           {'clouds': {'all': 92},
#            'dt': 1552197600,
#            'dt_txt': '2019-03-10 06:00:00',
#            'main': {'grnd_level': 963,
#                     'humidity': 97,
#                     'pressure': 978.9,
#                     'sea_level': 978.9,
#                     'temp': 279.349,
#                     'temp_kf': 0,
#                     'temp_max': 279.349,
#                     'temp_min': 279.349},
#            'rain': {'3h': 1.72},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 306.005, 'speed': 9.71}},
#           {'clouds': {'all': 80},
#            'dt': 1552208400,
#            'dt_txt': '2019-03-10 09:00:00',
#            'main': {'grnd_level': 978.77,
#                     'humidity': 95,
#                     'pressure': 994.44,
#                     'sea_level': 994.44,
#                     'temp': 276.703,
#                     'temp_kf': 0,
#                     'temp_max': 276.703,
#                     'temp_min': 276.703},
#            'rain': {'3h': 0.87},
#            'snow': {'3h': 0.01},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 322.004, 'speed': 15.16}},
#           {'clouds': {'all': 88},
#            'dt': 1552219200,
#            'dt_txt': '2019-03-10 12:00:00',
#            'main': {'grnd_level': 987.1,
#                     'humidity': 97,
#                     'pressure': 1003,
#                     'sea_level': 1003,
#                     'temp': 278.184,
#                     'temp_kf': 0,
#                     'temp_max': 278.184,
#                     'temp_min': 278.184},
#            'rain': {'3h': 1.03},
#            'snow': {},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 300.5, 'speed': 9.42}}],
#  'message': 0.0045}

# %%
weatherData["list"]
# Out:
# [{'dt': 1551798000,
#   'main': {'temp': 282.79,
#    'temp_min': 281.963,
#    'temp_max': 282.79,
#    'pressure': 994.63,
#    'sea_level': 994.63,
#    'grnd_level': 979.2,
#    'humidity': 77,
#    'temp_kf': 0.82},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 5.21, 'deg': 204.001},
#   'rain': {'3h': 0.145},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-05 15:00:00'},
#  {'dt': 1551808800,
#   'main': {'temp': 280.08,
#    'temp_min': 279.46,
#    'temp_max': 280.08,
#    'pressure': 992.12,
#    'sea_level': 992.12,
#    'grnd_level': 976.49,
#    'humidity': 96,
#    'temp_kf': 0.62},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 3.89, 'deg': 113.5},
#   'rain': {'3h': 1.87},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-05 18:00:00'},
#  {'dt': 1551819600,
#   'main': {'temp': 280.67,
#    'temp_min': 280.262,
#    'temp_max': 280.67,
#    'pressure': 988.1,
#    'sea_level': 988.1,
#    'grnd_level': 972.6,
#    'humidity': 95,
#    'temp_kf': 0.41},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 4.96, 'deg': 104.5},
#   'rain': {'3h': 4.22},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-05 21:00:00'},
#  {'dt': 1551830400,
#   'main': {'temp': 280.7,
#    'temp_min': 280.498,
#    'temp_max': 280.7,
#    'pressure': 982.61,
#    'sea_level': 982.61,
#    'grnd_level': 966.99,
#    'humidity': 96,
#    'temp_kf': 0.21},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 4.71, 'deg': 74.0031},
#   'rain': {'3h': 4.795},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-06 00:00:00'},
#  {'dt': 1551841200,
#   'main': {'temp': 281.403,
#    'temp_min': 281.403,
#    'temp_max': 281.403,
#    'pressure': 979.99,
#    'sea_level': 979.99,
#    'grnd_level': 964.45,
#    'humidity': 94,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 80},
#   'wind': {'speed': 3.07, 'deg': 195.5},
#   'rain': {'3h': 1.515},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-06 03:00:00'},
#  {'dt': 1551852000,
#   'main': {'temp': 281.593,
#    'temp_min': 281.593,
#    'temp_max': 281.593,
#    'pressure': 979.75,
#    'sea_level': 979.75,
#    'grnd_level': 964.31,
#    'humidity': 96,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 88},
#   'wind': {'speed': 5.47, 'deg': 210.004},
#   'rain': {'3h': 0.27},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-06 06:00:00'},
#  {'dt': 1551862800,
#   'main': {'temp': 282.035,
#    'temp_min': 282.035,
#    'temp_max': 282.035,
#    'pressure': 980.02,
#    'sea_level': 980.02,
#    'grnd_level': 964.39,
#    'humidity': 96,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 5.12, 'deg': 206.002},
#   'rain': {'3h': 1.18},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-06 09:00:00'},
#  {'dt': 1551873600,
#   'main': {'temp': 279.809,
#    'temp_min': 279.809,
#    'temp_max': 279.809,
#    'pressure': 980.78,
#    'sea_level': 980.78,
#    'grnd_level': 965.12,
#    'humidity': 100,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 6.16, 'deg': 329.002},
#   'rain': {'3h': 2.445},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-06 12:00:00'},
#  {'dt': 1551884400,
#   'main': {'temp': 278.257,
#    'temp_min': 278.257,
#    'temp_max': 278.257,
#    'pressure': 982.22,
#    'sea_level': 982.22,
#    'grnd_level': 966.76,
#    'humidity': 98,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 88},
#   'wind': {'speed': 8.16, 'deg': 326},
#   'rain': {'3h': 1.195},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-06 15:00:00'},
#  {'dt': 1551895200,
#   'main': {'temp': 278.981,
#    'temp_min': 278.981,
#    'temp_max': 278.981,
#    'pressure': 984.46,
#    'sea_level': 984.46,
#    'grnd_level': 968.85,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 7.58, 'deg': 316.5},
#   'rain': {'3h': 0.069999999999997},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-06 18:00:00'},
#  {'dt': 1551906000,
#   'main': {'temp': 278.782,
#    'temp_min': 278.782,
#    'temp_max': 278.782,
#    'pressure': 987.13,
#    'sea_level': 987.13,
#    'grnd_level': 971.43,
#    'humidity': 90,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 7.26, 'deg': 302.5},
#   'rain': {'3h': 0.075000000000003},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-06 21:00:00'},
#  {'dt': 1551916800,
#   'main': {'temp': 278.309,
#    'temp_min': 278.309,
#    'temp_max': 278.309,
#    'pressure': 989.02,
#    'sea_level': 989.02,
#    'grnd_level': 973.36,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 7.66, 'deg': 301.003},
#   'rain': {'3h': 0.074999999999999},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-07 00:00:00'},
#  {'dt': 1551927600,
#   'main': {'temp': 277.596,
#    'temp_min': 277.596,
#    'temp_max': 277.596,
#    'pressure': 990.6,
#    'sea_level': 990.6,
#    'grnd_level': 974.9,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 48},
#   'wind': {'speed': 8.17, 'deg': 297.506},
#   'rain': {'3h': 0.004999999999999},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-07 03:00:00'},
#  {'dt': 1551938400,
#   'main': {'temp': 277.501,
#    'temp_min': 277.501,
#    'temp_max': 277.501,
#    'pressure': 992.08,
#    'sea_level': 992.08,
#    'grnd_level': 976.39,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 76},
#   'wind': {'speed': 8.61, 'deg': 295.001},
#   'rain': {'3h': 0.025000000000002},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-07 06:00:00'},
#  {'dt': 1551949200,
#   'main': {'temp': 278.857,
#    'temp_min': 278.857,
#    'temp_max': 278.857,
#    'pressure': 994.84,
#    'sea_level': 994.84,
#    'grnd_level': 979.17,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 76},
#   'wind': {'speed': 9.51, 'deg': 301.006},
#   'rain': {'3h': 0.064999999999998},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-07 09:00:00'},
#  {'dt': 1551960000,
#   'main': {'temp': 281.593,
#    'temp_min': 281.593,
#    'temp_max': 281.593,
#    'pressure': 997.74,
#    'sea_level': 997.74,
#    'grnd_level': 982.06,
#    'humidity': 75,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 36},
#   'wind': {'speed': 10.12, 'deg': 310.003},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-07 12:00:00'},
#  {'dt': 1551970800,
#   'main': {'temp': 282.017,
#    'temp_min': 282.017,
#    'temp_max': 282.017,
#    'pressure': 1000.74,
#    'sea_level': 1000.74,
#    'grnd_level': 985.1,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 64},
#   'wind': {'speed': 8.82, 'deg': 313.5},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-07 15:00:00'},
#  {'dt': 1551981600,
#   'main': {'temp': 280.7,
#    'temp_min': 280.7,
#    'temp_max': 280.7,
#    'pressure': 1004.18,
#    'sea_level': 1004.18,
#    'grnd_level': 988.33,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 56},
#   'wind': {'speed': 6.56, 'deg': 308.502},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-07 18:00:00'},
#  {'dt': 1551992400,
#   'main': {'temp': 278.5,
#    'temp_min': 278.5,
#    'temp_max': 278.5,
#    'pressure': 1007.64,
#    'sea_level': 1007.64,
#    'grnd_level': 991.66,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 32},
#   'wind': {'speed': 4.56, 'deg': 298.5},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-07 21:00:00'},
#  {'dt': 1552003200,
#   'main': {'temp': 275.168,
#    'temp_min': 275.168,
#    'temp_max': 275.168,
#    'pressure': 1009.24,
#    'sea_level': 1009.24,
#    'grnd_level': 993.15,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 20},
#   'wind': {'speed': 2.87, 'deg': 252.507},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-08 00:00:00'},
#  {'dt': 1552014000,
#   'main': {'temp': 274.328,
#    'temp_min': 274.328,
#    'temp_max': 274.328,
#    'pressure': 1009.38,
#    'sea_level': 1009.38,
#    'grnd_level': 993.36,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 68},
#   'wind': {'speed': 3.22, 'deg': 217.503},
#   'rain': {'3h': 0.010000000000002},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-08 03:00:00'},
#  {'dt': 1552024800,
#   'main': {'temp': 275.999,
#    'temp_min': 275.999,
#    'temp_max': 275.999,
#    'pressure': 1008.29,
#    'sea_level': 1008.29,
#    'grnd_level': 992.26,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 80},
#   'wind': {'speed': 3.97, 'deg': 197.501},
#   'rain': {'3h': 0.029999999999998},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-08 06:00:00'},
#  {'dt': 1552035600,
#   'main': {'temp': 278.316,
#    'temp_min': 278.316,
#    'temp_max': 278.316,
#    'pressure': 1006.13,
#    'sea_level': 1006.13,
#    'grnd_level': 990.3,
#    'humidity': 95,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 6.12, 'deg': 187.002},
#   'rain': {'3h': 0.9},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-08 09:00:00'},
#  {'dt': 1552046400,
#   'main': {'temp': 281.107,
#    'temp_min': 281.107,
#    'temp_max': 281.107,
#    'pressure': 1003.62,
#    'sea_level': 1003.62,
#    'grnd_level': 987.86,
#    'humidity': 97,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 7.96, 'deg': 206},
#   'rain': {'3h': 1.52},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-08 12:00:00'},
#  {'dt': 1552057200,
#   'main': {'temp': 283.07,
#    'temp_min': 283.07,
#    'temp_max': 283.07,
#    'pressure': 1001.66,
#    'sea_level': 1001.66,
#    'grnd_level': 985.98,
#    'humidity': 96,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 6.16, 'deg': 231.501},
#   'rain': {'3h': 0.3},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-08 15:00:00'},
#  {'dt': 1552068000,
#   'main': {'temp': 282.221,
#    'temp_min': 282.221,
#    'temp_max': 282.221,
#    'pressure': 1001.17,
#    'sea_level': 1001.17,
#    'grnd_level': 985.62,
#    'humidity': 90,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 76},
#   'wind': {'speed': 5.11, 'deg': 269.502},
#   'rain': {'3h': 0.09},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-08 18:00:00'},
#  {'dt': 1552078800,
#   'main': {'temp': 280.539,
#    'temp_min': 280.539,
#    'temp_max': 280.539,
#    'pressure': 1001.31,
#    'sea_level': 1001.31,
#    'grnd_level': 985.68,
#    'humidity': 95,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 5.21, 'deg': 245},
#   'rain': {'3h': 0.07},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-08 21:00:00'},
#  {'dt': 1552089600,
#   'main': {'temp': 280.968,
#    'temp_min': 280.968,
#    'temp_max': 280.968,
#    'pressure': 1000.84,
#    'sea_level': 1000.84,
#    'grnd_level': 985.17,
#    'humidity': 96,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 6.86, 'deg': 252.004},
#   'rain': {'3h': 0.42},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-09 00:00:00'},
#  {'dt': 1552100400,
#   'main': {'temp': 279.739,
#    'temp_min': 279.739,
#    'temp_max': 279.739,
#    'pressure': 1001.22,
#    'sea_level': 1001.22,
#    'grnd_level': 985.4,
#    'humidity': 92,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 76},
#   'wind': {'speed': 7.17, 'deg': 274},
#   'rain': {'3h': 0.26},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-09 03:00:00'},
#  {'dt': 1552111200,
#   'main': {'temp': 279.204,
#    'temp_min': 279.204,
#    'temp_max': 279.204,
#    'pressure': 1000.48,
#    'sea_level': 1000.48,
#    'grnd_level': 984.64,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 68},
#   'wind': {'speed': 8.83, 'deg': 240.003},
#   'rain': {'3h': 0.28},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-09 06:00:00'},
#  {'dt': 1552122000,
#   'main': {'temp': 278.743,
#    'temp_min': 278.743,
#    'temp_max': 278.743,
#    'pressure': 1003.57,
#    'sea_level': 1003.57,
#    'grnd_level': 987.81,
#    'humidity': 87,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 44},
#   'wind': {'speed': 10.35, 'deg': 284.502},
#   'rain': {'3h': 0.81},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-09 09:00:00'},
#  {'dt': 1552132800,
#   'main': {'temp': 280.556,
#    'temp_min': 280.556,
#    'temp_max': 280.556,
#    'pressure': 1007.38,
#    'sea_level': 1007.38,
#    'grnd_level': 991.68,
#    'humidity': 75,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 20},
#   'wind': {'speed': 12.25, 'deg': 271.5},
#   'rain': {'3h': 0.65},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-09 12:00:00'},
#  {'dt': 1552143600,
#   'main': {'temp': 281.516,
#    'temp_min': 281.516,
#    'temp_max': 281.516,
#    'pressure': 1009.52,
#    'sea_level': 1009.52,
#    'grnd_level': 993.68,
#    'humidity': 63,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 56},
#   'wind': {'speed': 10.96, 'deg': 275.002},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-09 15:00:00'},
#  {'dt': 1552154400,
#   'main': {'temp': 279.75,
#    'temp_min': 279.75,
#    'temp_max': 279.75,
#    'pressure': 1008.29,
#    'sea_level': 1008.29,
#    'grnd_level': 992.48,
#    'humidity': 65,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 68},
#   'wind': {'speed': 4.82, 'deg': 259.003},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-09 18:00:00'},
#  {'dt': 1552165200,
#   'main': {'temp': 277.639,
#    'temp_min': 277.639,
#    'temp_max': 277.639,
#    'pressure': 1004.22,
#    'sea_level': 1004.22,
#    'grnd_level': 988.33,
#    'humidity': 92,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 4.91, 'deg': 180.5},
#   'rain': {'3h': 0.73},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-09 21:00:00'},
#  {'dt': 1552176000,
#   'main': {'temp': 278.343,
#    'temp_min': 278.343,
#    'temp_max': 278.343,
#    'pressure': 992.58,
#    'sea_level': 992.58,
#    'grnd_level': 976.83,
#    'humidity': 95,
#    'temp_kf': 0},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 9.63, 'deg': 152.003},
#   'rain': {'3h': 5.89},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-10 00:00:00'},
#  {'dt': 1552186800,
#   'main': {'temp': 278.704,
#    'temp_min': 278.704,
#    'temp_max': 278.704,
#    'pressure': 981.22,
#    'sea_level': 981.22,
#    'grnd_level': 965.55,
#    'humidity': 95,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 10.57, 'deg': 193.505},
#   'rain': {'3h': 1.92},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-10 03:00:00'},
#  {'dt': 1552197600,
#   'main': {'temp': 279.349,
#    'temp_min': 279.349,
#    'temp_max': 279.349,
#    'pressure': 978.9,
#    'sea_level': 978.9,
#    'grnd_level': 963,
#    'humidity': 97,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 9.71, 'deg': 306.005},
#   'rain': {'3h': 1.72},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-03-10 06:00:00'},
#  {'dt': 1552208400,
#   'main': {'temp': 276.703,
#    'temp_min': 276.703,
#    'temp_max': 276.703,
#    'pressure': 994.44,
#    'sea_level': 994.44,
#    'grnd_level': 978.77,
#    'humidity': 95,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 80},
#   'wind': {'speed': 15.16, 'deg': 322.004},
#   'rain': {'3h': 0.87},
#   'snow': {'3h': 0.01},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-10 09:00:00'},
#  {'dt': 1552219200,
#   'main': {'temp': 278.184,
#    'temp_min': 278.184,
#    'temp_max': 278.184,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 987.1,
#    'humidity': 97,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 88},
#   'wind': {'speed': 9.42, 'deg': 300.5},
#   'rain': {'3h': 1.03},
#   'snow': {},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-03-10 12:00:00'}]
